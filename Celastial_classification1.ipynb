# %% [markdown]
# <a href="https://colab.research.google.com/github/aswathi-859/project_nov/blob/master/Celastial_classification1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                                                      CELESTIAL CLASSIFICATION

# %%
import pandas as pd
df=pd.read_csv('/content/star_classification.csv')
df.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    run_ID  cam_col  field_ID   spec_obj_ID   class  redshift    plate  \
# 0    3606      2.0      79.0  6.543780e+18  GALAXY  0.634794   5812.0
# 1    4518      5.0     119.0  1.176010e+19  GALAXY  0.779136  10445.0
# 2    3606      2.0     120.0  5.152200e+18  GALAXY  0.644195   4576.0
# 3    4192      3.0     214.0  1.030110e+19  GALAXY  0.932346   9149.0
# 4    8102      3.0     137.0  6.891860e+18  GALAXY  0.116123   6121.0
#
#        MJD  fiber_ID
# 0  56354.0     171.0
# 1  58158.0     427.0
# 2  55592.0     299.0
# ...

# %%
df.tail()
# Out:
#             alpha      delta         u         g         r         i  \
# 17067  355.954970  38.574967  16.99098  16.52928  16.68446  16.84429
# 17068  351.098813   0.033171  22.97222  22.90839  22.27260  21.82701
# 17069  186.611382  -1.430202  19.01196  18.02943  17.76186  17.64646
# 17070  186.811336  -1.288225  21.13047  20.31622  20.08687  20.00548
# 17071  237.656324  51.297834  23.21091  22.25876  20.59093  19.61795
#
#               z  run_ID  cam_col  field_ID   spec_obj_ID   class  redshift  \
# 17067  17.02662    4135      1.0     210.0  2.119020e+18    STAR -0.000217
# 17068  21.36924    4263      4.0      56.0  9.868660e+18  GALAXY  0.843711
# 17069  17.61514    1140      6.0     225.0  3.761540e+17    STAR  0.001197
# 17070  19.64249    1140      6.0     226.0  4.269600e+18    STAR  0.000688
# 17071  19.00928      22      NaN       NaN           NaN     NaN       NaN
#
#         plate      MJD  fiber_ID
# 17067  1882.0  53262.0     291.0
# ...

# %%
print(df.size)
print(df.ndim)
print(df.shape)
print(df.columns)
# Out:
# 273152
# 2
# (17072, 16)
# Index(['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID', 'cam_col',
#        'field_ID', 'spec_obj_ID', 'class', 'redshift', 'plate', 'MJD',
#        'fiber_ID'],
#       dtype='object')

# %%
for i in df.columns:
  print(df[i].unique(),i)
  print('*'*100)
  print(df[i].value_counts(),i)
  print('*'*100)
# Out:
# [135.6891066 144.8261006 142.1887896 ... 186.6113816 186.8113359
#  237.6563241] alpha
# ****************************************************************************************************
# alpha
# 116.844429    1
# 349.674554    1
# 232.746218    1
# 248.696564    1
# 209.419145    1
#              ..
# 345.282593    1
# 338.741038    1
# 142.188790    1
# 144.826101    1
# 135.689107    1
# Name: count, Length: 17072, dtype: int64 alpha
# ****************************************************************************************************
# [32.49463184 31.27418489 35.58244418 ... -1.43020229 -1.28822463
#  51.29783445] delta
# ****************************************************************************************************
# delta
#  36.936705    1
#  22.715169    1
#  61.248661    1
#  39.399451    1
#  12.510207    1
#              ..
#  21.183866    1
# -0.402828     1
#  35.582444    1
#  31.274185    1
#  32.494632    1
# Name: count, Length: 17072, dtype: int64 delta
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17072 entries, 0 to 17071
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   alpha        17072 non-null  float64
#  1   delta        17072 non-null  float64
#  2   u            17072 non-null  float64
#  3   g            17072 non-null  float64
#  4   r            17072 non-null  float64
#  5   i            17072 non-null  float64
#  6   z            17072 non-null  float64
#  7   run_ID       17072 non-null  int64
#  8   cam_col      17071 non-null  float64
#  9   field_ID     17071 non-null  float64
#  10  spec_obj_ID  17071 non-null  float64
#  11  class        17071 non-null  object
#  12  redshift     17071 non-null  float64
#  13  plate        17071 non-null  float64
#  14  MJD          17071 non-null  float64
#  15  fiber_ID     17071 non-null  float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#               alpha         delta             u             g             r  \
# count  17072.000000  17072.000000  17072.000000  17072.000000  17072.000000
# mean     176.568567     22.435432     22.077948     20.631793     19.654810
# std      101.102580     18.932488      2.244672      2.034537      1.855482
# min        0.005528    -13.917324     12.262400     10.511390      9.822070
# 25%      123.912043      3.583742     20.363608     19.003385     18.156770
# 50%      177.650286     20.539371     22.165550     21.066120     20.127045
# 75%      236.962601     36.892795     23.673202     22.117300     21.046975
# max      359.999810     82.764421     29.199010     31.602240     27.397090
#
#                   i             z        run_ID       cam_col      field_ID  \
# count  17072.000000  17072.000000  17072.000000  17071.000000  17071.000000
# mean      19.101952     18.789936   4653.372247      3.487669    185.272450
# ...

# %%
df.isna().sum()
# Out:
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# cam_col        1
# field_ID       1
# spec_obj_ID    1
# class          1
# redshift       1
# plate          1
# MJD            1
# fiber_ID       1
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# alpha          0.000000
# delta          0.000000
# u              0.000000
# g              0.000000
# r              0.000000
# i              0.000000
# z              0.000000
# run_ID         0.000000
# cam_col        0.005858
# field_ID       0.005858
# spec_obj_ID    0.005858
# class          0.005858
# redshift       0.005858
# plate          0.005858
# MJD            0.005858
# fiber_ID       0.005858
# dtype: float64

# %%
df.ffill(inplace=True)
df.isna().sum()
# Out:
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['class']=le.fit_transform(df['class'])
df.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    run_ID  cam_col  field_ID   spec_obj_ID  class  redshift    plate      MJD  \
# 0    3606      2.0      79.0  6.543780e+18      0  0.634794   5812.0  56354.0
# 1    4518      5.0     119.0  1.176010e+19      0  0.779136  10445.0  58158.0
# 2    3606      2.0     120.0  5.152200e+18      0  0.644195   4576.0  55592.0
# 3    4192      3.0     214.0  1.030110e+19      0  0.932346   9149.0  58039.0
# 4    8102      3.0     137.0  6.891860e+18      0  0.116123   6121.0  56187.0
#
#    fiber_ID
# 0     171.0
# 1     427.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for i in df.columns:
   sns.boxplot(x=df[i])
   plt.show()

# %%
df.corr()['class']
# Out:
# alpha         -0.025347
# delta          0.028578
# u             -0.249636
# g             -0.203386
# r             -0.051026
# i              0.039768
# z              0.091904
# run_ID        -0.025525
# cam_col        0.000799
# field_ID      -0.063993
# spec_obj_ID    0.008172
# class          1.000000
# redshift      -0.043653
# plate          0.008187
# MJD            0.020023
# fiber_ID      -0.017081
# Name: class, dtype: float64

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
y_train.value_counts()
# Out:
# class
# 0    8123
# 2    2914
# 1    2620
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_train,y_train=sm.fit_resample(x_train,y_train)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
ypred=knn.predict(x_test)
ypred
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
train_score=knn.score(x_train,y_train)
print(train_score)
test_score=knn.score(x_test,y_test)
print(test_score)
# Out:
# 0.9571586852148221
# 0.8907759882869692

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypred))
print(precision_score(y_test,ypred,average='weighted'))
print(recall_score(y_test,ypred,average='weighted'))
print(f1_score(y_test,ypred,average='weighted'))
print(confusion_matrix(y_test,ypred))
print(classification_report(y_test,ypred))
# Out:
# 0.8907759882869692
# 0.8918158826419705
# 0.8907759882869692
# 0.8911806041301034
# [[1848   61  122]
#  [  55  577   23]
#  [ 100   12  617]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      2031
#            1       0.89      0.88      0.88       655
#            2       0.81      0.85      0.83       729
#
#     accuracy                           0.89      3415
#    macro avg       0.87      0.88      0.88      3415
# weighted avg       0.89      0.89      0.89      3415

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
ypred=nb.predict(x_test)
ypred
# Out:
# array([1, 2, 1, ..., 1, 0, 0])

# %%
train_score=nb.score(x_train,y_train)
print(train_score)
test_score=nb.score(x_test,y_test)
print(test_score)
# Out:
# 0.8974516804136403
# 0.8653001464128843

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypred))
print(precision_score(y_test,ypred,average='weighted'))
print(recall_score(y_test,ypred,average='weighted'))
print(f1_score(y_test,ypred,average='weighted'))
print(confusion_matrix(y_test,ypred))
print(classification_report(y_test,ypred))
# Out:
# 0.8653001464128843
# 0.8971811861892381
# 0.8653001464128843
# 0.8725235524578089
# [[1657  363   11]
#  [  68  587    0]
#  [   3   15  711]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88      2031
#            1       0.61      0.90      0.72       655
#            2       0.98      0.98      0.98       729
#
#     accuracy                           0.87      3415
#    macro avg       0.85      0.90      0.86      3415
# weighted avg       0.90      0.87      0.87      3415

# %%
from sklearn.feature_selection import SelectKBest
bestfeatures=SelectKBest(k='all')
fit=bestfeatures.fit(x,y)
print(fit.scores_)
# Out:
# [8.52007083e+00 3.48778760e+01 6.05861604e+02 4.95895427e+02
#  6.87155582e+02 1.31285436e+03 1.61691691e+03 3.82186272e+01
#  1.80025111e+01 4.12402120e+01 7.69759975e+02 1.42227209e+04
#  7.69810592e+02 6.76711297e+02 4.44879595e+01]

# %%
dfscores=pd.DataFrame(fit.scores_)
dfcolumns=pd.DataFrame(x.columns)

fs=pd.concat([dfcolumns,dfscores],axis=1)
fs.columns=['features','scores']
fs
# Out:
#        features        scores
# 0         alpha      8.520071
# 1         delta     34.877876
# 2             u    605.861604
# 3             g    495.895427
# 4             r    687.155582
# 5             i   1312.854355
# 6             z   1616.916907
# 7        run_ID     38.218627
# 8       cam_col     18.002511
# 9      field_ID     41.240212
# 10  spec_obj_ID    769.759975
# 11     redshift  14222.720863
# 12        plate    769.810592
# 13          MJD    676.711297
# 14     fiber_ID     44.487960

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=5,criterion='entropy',splitter='best',min_samples_split=5)
dt.fit(x_train,y_train)
ypread=dt.predict(x_test)
ypread
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
train_score=dt.score(x_train,y_train)
print(train_score)
test_score=dt.score(x_test,y_test)
print(test_score)
# Out:
# 0.967499692231934
# 0.9692532942898975

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypread))
print(precision_score(y_test,ypread,average='weighted'))
print(recall_score(y_test,ypread,average='weighted'))
print(f1_score(y_test,ypread,average='weighted'))
print(confusion_matrix(y_test,ypread))
print(classification_report(y_test,ypread))
# Out:
# 0.9692532942898975
# 0.9690148649142659
# 0.9692532942898975
# 0.969069670208094
# [[1986   38    7]
#  [  60  595    0]
#  [   0    0  729]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      2031
#            1       0.94      0.91      0.92       655
#            2       0.99      1.00      1.00       729
#
#     accuracy                           0.97      3415
#    macro avg       0.97      0.96      0.96      3415
# weighted avg       0.97      0.97      0.97      3415

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear')
svm.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
ypred=svm.predict(x_test)

# %%
train_score=svm.score(x_train,y_train)
print(train_score)
test_score=svm.score(x_test,y_test)
print(test_score)
# Out:
# 0.9610570807173048
# 0.9505124450951684

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,ypread))
print(precision_score(y_test,ypread,average='weighted'))
print(recall_score(y_test,ypread,average='weighted'))
print(f1_score(y_test,ypread,average='weighted'))
print(confusion_matrix(y_test,ypread))
print(classification_report(y_test,ypread))
# Out:
# 0.9692532942898975
# 0.9690148649142659
# 0.9692532942898975
# 0.969069670208094
# [[1986   38    7]
#  [  60  595    0]
#  [   0    0  729]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      2031
#            1       0.94      0.91      0.92       655
#            2       0.99      1.00      1.00       729
#
#     accuracy                           0.97      3415
#    macro avg       0.97      0.96      0.96      3415
# weighted avg       0.97      0.97      0.97      3415

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
training_score=model.score(x_train,y_train)
testing_score=model.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.9556813984980919
# 0.9426061493411421

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9426061493411421
# 0.9444283355955742
# 0.9426061493411421
# 0.9426511924408794
# [[1894   50   87]
#  [  59  596    0]
#  [   0    0  729]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      2031
#            1       0.92      0.91      0.92       655
#            2       0.89      1.00      0.94       729
#
#     accuracy                           0.94      3415
#    macro avg       0.93      0.95      0.94      3415
# weighted avg       0.94      0.94      0.94      3415

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=20,criterion='gini',max_depth=5,max_features=5)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=5, n_estimators=20)

# %%
ypred=rfc.predict(x_test)
ypred
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
train_score=rfc.score(x_train,y_train)
print(train_score)
test_score=rfc.score(x_test,y_test)
print(test_score)
# Out:
# 0.9677869424268538
# 0.9642752562225476

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9426061493411421
# 0.9444283355955742
# 0.9426061493411421
# 0.9426511924408794
# [[1894   50   87]
#  [  59  596    0]
#  [   0    0  729]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      2031
#            1       0.92      0.91      0.92       655
#            2       0.89      1.00      0.94       729
#
#     accuracy                           0.94      3415
#    macro avg       0.93      0.95      0.94      3415
# weighted avg       0.94      0.94      0.94      3415

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
ada=AdaBoostClassifier()
print(ada.estimator)
# Out:
# None

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
ada=AdaBoostClassifier(estimator=lr)
print(ada.estimator)
# Out:
# LogisticRegression()

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
print(ada.estimator)
# Out:
# None

# %%
y_pred=ada.predict(x_test)

# %%
training_score=ada.score(x_train,y_train)
testing_score=ada.score(x_test,y_test)
print(training_score)
print(testing_score)
# Out:
# 0.9414830317206286
# 0.9335285505124451

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred,average='weighted'))
print(recall_score(y_test,y_pred,average='weighted'))
print(f1_score(y_test,y_pred,average='weighted'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9335285505124451
# 0.9345152005635655
# 0.9335285505124451
# 0.9338507412598569
# [[1895  120   16]
#  [  91  564    0]
#  [   0    0  729]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      2031
#            1       0.82      0.86      0.84       655
#            2       0.98      1.00      0.99       729
#
#     accuracy                           0.93      3415
#    macro avg       0.92      0.93      0.93      3415
# weighted avg       0.93      0.93      0.93      3415

# %%
import pickle
pickle.dump(dt,open('model.pkl','wb'))

# %%
import pickle
pickle.dump(sc,open('scaler.pkl','wb'))

# %%
pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.7.0
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.1
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.1.0
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .
